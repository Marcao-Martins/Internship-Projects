# %% [markdown]
# Aqui estão as explicações para o funcionamento do notebook Jupyter:
#
# ---
#
# ### 1. Importações de Bibliotecas e Definições Iniciais
#
# Este trecho de código é responsável por importar as bibliotecas necessárias para o projeto, como `logging`, `os`, `pandas`, `spacy`, `torch`, entre outras. Além disso, são importados módulos específicos do projeto, como `DanteTokenizer` e funções de pré-processamento.
#
# Também são definidos modelos disponíveis e pré-processadores específicos para cada tipo de dados.
#
# ---
# Em resumo, basta definir os valores das variáveis da sessão 2 e executar todas as células em ordem.

# %%
import logging
import os
from typing import List, Tuple
import pandas as pd
import spacy
import torch
from dante_tokenizer import DanteTokenizer
from transformers import AutoModelForTokenClassification, AutoTokenizer

from dante_tokenizer.data.preprocessing import split_monetary_tokens, normalize_text, split_enclisis

from preprocessing import *

try:
    nlp = spacy.load("pt_core_news_sm")
except Exception:
    os.system("python -m spacy download pt_core_news_sm")
    nlp = spacy.load("pt_core_news_sm")
dt_tokenizer = DanteTokenizer()

model_choices = {
    "News": "Emanuel/porttagger-news-base",
    "Tweets (stock market)": "Emanuel/porttagger-tweets-base",
    "Oil and Gas (academic texts)": "Emanuel/porttagger-oilgas-base",
    "Multigenre": "Emanuel/porttagger-base",
}
pre_tokenizers = {
    "News": nlp,
    "Tweets (stock market)": dt_tokenizer.tokenize,
    "Oil and Gas (academic texts)": nlp,
    "Multigenre": nlp,
}

# %% [markdown]
# ### 2. Definições de Variáveis e Configurações
#
# Neste trecho, são definidas variáveis como o modelo padrão a ser utilizado (`default_model`), o nome da coluna de identificação (`id_column`), o nome da coluna de conteúdo (`content_column`), o caminho dos dados de entrada (`data_path`), o caminho de saída (`output_path`), e uma configuração para manter ou substituir contrações (`keep_replace_contraction`).
#
# Também é configurado o nível de log para `DEBUG`.

# %%
default_model = "Tweets (stock market)"
id_column = 'ID'
content_column = 'Text'
prefix = 'dante_01'
data_path = r'C:\Users\Marcos\Desktop\tic\bases\danteV2.1.csv'
output_path = r'C:\Users\Marcos\Desktop\tic\comparação\tagger\DANTEStocksV2.1_reconstruido.conllu'
keep_replace_contraction = True

logger = logging.getLogger()
logger.setLevel(logging.DEBUG)

# %% [markdown]
# ### 3. Classe `MyApp`
#
# Esta classe é responsável por carregar o modelo selecionado utilizando a função `load_model`.

# %%
class MyApp:
    def __init__(self) -> None:
        self.model = None
        self.tokenizer = None
        self.pre_tokenizer = None
        self.load_model()

    def load_model(self, model_name: str = default_model):
        if model_name not in model_choices.keys():
            logger.error("Selected model is not supported, resetting to the default model.")
            model_name = default_model
        self.model = AutoModelForTokenClassification.from_pretrained(model_choices[model_name])
        self.tokenizer = AutoTokenizer.from_pretrained(model_choices[model_name])
        self.pre_tokenizer = pre_tokenizers[model_name]

myapp = MyApp()

# %% [markdown]
# ### 4. Função `predict`
#
# Esta função recebe um texto como entrada e faz previsões utilizando o modelo carregado pela instância de `MyApp`. A função tokeniza o texto, faz previsões de tokenização e retorna os tokens, as etiquetas preditas e as pontuações associadas a essas previsões.

# %%
print_counter = 1

def predict(text, logger=None) -> Tuple[List[str], List[str]]:
    global print_counter  # Utilize a variável global
    doc = myapp.pre_tokenizer(text)
    tokens = [token.text if not isinstance(token, str) else token for token in doc]

    logger.info("Starting predictions for sentence: {}".format(text))
    
    # Print com contador
    print("Using model {} - Prediction count: {}".format(myapp.model.config.__dict__["_name_or_path"], print_counter))
    
    # Incrementa o contador
    print_counter += 1

    input_tokens = myapp.tokenizer(
        tokens,
        return_tensors="pt",
        is_split_into_words=True,
        return_offsets_mapping=True,
        return_special_tokens_mask=True,
        max_length=512,  # Limite de tokens
        truncation=True,  # Truncar a sequência se ela for maior que 512
        padding="max_length"  # Preencher até 512 tokens, se necessário
    )
    output = myapp.model(input_tokens["input_ids"])

    i_token = 0
    labels = []
    scores = []
    for off, is_special_token, pred in zip(
        input_tokens["offset_mapping"][0],
        input_tokens["special_tokens_mask"][0],
        output.logits[0],
    ):
        if is_special_token or off[0] > 0:
            continue
        label = myapp.model.config.__dict__["id2label"][int(pred.argmax(axis=-1))]
        if logger is not None:
            logger.info("{}, {}, {}".format(off, tokens[i_token], label))
        labels.append(label)
        scores.append(
            "{:.2f}".format(100 * float(torch.softmax(pred, dim=-1).detach().max()))
        )
        i_token += 1

    return tokens, labels, scores

# %% [markdown]
# ### 5. Função `batch_analysis_csv`
#
# Esta função realiza uma análise em lote de um arquivo CSV, onde cada linha do CSV contém um texto a ser analisado. Ela carrega o arquivo CSV, processa os textos, faz previsões para cada texto utilizando a função `predict`, e gera um arquivo de saída no formato CoNLL-U contendo as previsões feitas pelo modelo.

# %%
def batch_analysis_csv(id_column: str, content_column: str, data_path: str, prefix: str, output_path: str, keep_replace_contraction: bool):
    # Carregar o arquivo CSV no DataFrame
    df = pd.read_csv(data_path)
    ids = df[id_column]
    texts = df[content_column]
    
    # Substituir quebras de linha por espaços
    texts = texts.replace(r'\\n', ' ', regex=True) 

    # Converter valores para string para evitar erro com float e aplicar strip
    texts = texts.astype(str).apply(lambda x: x.strip()) # Garantir que todos os valores são strings antes de aplicar strip

    conllu_output = []

    for id, sent in zip(ids, texts):
        #print(sent)
        
        conllu_output.append("# sent_id = {}_{}\n".format(prefix, id))
        conllu_output.append("# text = {}\n".format(sent))
        
        tokens, labels, _ = predict(sent, logger)
        tokens_labels = list(zip(tokens, labels))

        for j, (token, label) in enumerate(tokens_labels):
            #print(tokens_labels[j][0])
            try:
                contr = tokens_labels[j][0] + ' ' + tokens_labels[j+1][0]
                for expansion in expansions.keys():
                    replace_str = expansions[expansion]
                    match = re.match(expansion, contr, re.IGNORECASE)
                    expansion = replace_keep_case(expansion, replace_str, contr)
                    if match is not None:
                        conllu_output.append("{}\t{}".format(str(j+1)+'-'+str(j+2), expansion) + "\t_" * 8 + "\n")
                        break
                conllu_output.append("{}\t{}\t_\t{}".format(j + 1, token, label) + "\t_" * 6 + "\n")

            except IndexError:
                conllu_output.append("{}\t{}\t_\t{}".format(j + 1, token, label) + "\t_" * 6 + "\n")
            
        conllu_output.append("\n")

    with open(output_path, 'w', encoding='utf-8') as out_f:
        out_f.writelines(conllu_output)

# %% [markdown]
# ### 6. Execução do Processamento em Lote
#
# Neste trecho, a função `batch_analysis_csv` é chamada com os parâmetros previamente definidos. Isso inicia o processo de análise em lote dos dados contidos no arquivo CSV especificado, utilizando o modelo padrão e as configurações definidas anteriormente.

# %%
batch_analysis_csv(id_column, content_column, data_path, prefix, output_path, keep_replace_contraction)
# Out:
# We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See https://huggingface.co/docs/transformers/troubleshooting#incorrect-output-when-padding-tokens-arent-masked.
# Using model Emanuel/porttagger-tweets-base - Prediction count: 1
# Using model Emanuel/porttagger-tweets-base - Prediction count: 2
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4
# Using model Emanuel/porttagger-tweets-base - Prediction count: 5
# Using model Emanuel/porttagger-tweets-base - Prediction count: 6
# Using model Emanuel/porttagger-tweets-base - Prediction count: 7
# Using model Emanuel/porttagger-tweets-base - Prediction count: 8
# Using model Emanuel/porttagger-tweets-base - Prediction count: 9
# Using model Emanuel/porttagger-tweets-base - Prediction count: 10
# Using model Emanuel/porttagger-tweets-base - Prediction count: 11
# Using model Emanuel/porttagger-tweets-base - Prediction count: 12
# Using model Emanuel/porttagger-tweets-base - Prediction count: 13
# Using model Emanuel/porttagger-tweets-base - Prediction count: 14
# Using model Emanuel/porttagger-tweets-base - Prediction count: 15
# Using model Emanuel/porttagger-tweets-base - Prediction count: 16
# Using model Emanuel/porttagger-tweets-base - Prediction count: 17
# Using model Emanuel/porttagger-tweets-base - Prediction count: 18
# Using model Emanuel/porttagger-tweets-base - Prediction count: 19
# Using model Emanuel/porttagger-tweets-base - Prediction count: 20
# Using model Emanuel/porttagger-tweets-base - Prediction count: 21
# Using model Emanuel/porttagger-tweets-base - Prediction count: 22
# Using model Emanuel/porttagger-tweets-base - Prediction count: 23
# Using model Emanuel/porttagger-tweets-base - Prediction count: 24
# Using model Emanuel/porttagger-tweets-base - Prediction count: 25
# Using model Emanuel/porttagger-tweets-base - Prediction count: 26
# Using model Emanuel/porttagger-tweets-base - Prediction count: 27
# Using model Emanuel/porttagger-tweets-base - Prediction count: 28
# Using model Emanuel/porttagger-tweets-base - Prediction count: 29
# Using model Emanuel/porttagger-tweets-base - Prediction count: 30
# Using model Emanuel/porttagger-tweets-base - Prediction count: 31
# Using model Emanuel/porttagger-tweets-base - Prediction count: 32
# Using model Emanuel/porttagger-tweets-base - Prediction count: 33
# Using model Emanuel/porttagger-tweets-base - Prediction count: 34
# Using model Emanuel/porttagger-tweets-base - Prediction count: 35
# Using model Emanuel/porttagger-tweets-base - Prediction count: 36
# Using model Emanuel/porttagger-tweets-base - Prediction count: 37
# Using model Emanuel/porttagger-tweets-base - Prediction count: 38
# Using model Emanuel/porttagger-tweets-base - Prediction count: 39
# Using model Emanuel/porttagger-tweets-base - Prediction count: 40
# Using model Emanuel/porttagger-tweets-base - Prediction count: 41
# Using model Emanuel/porttagger-tweets-base - Prediction count: 42
# Using model Emanuel/porttagger-tweets-base - Prediction count: 43
# Using model Emanuel/porttagger-tweets-base - Prediction count: 44
# Using model Emanuel/porttagger-tweets-base - Prediction count: 45
# Using model Emanuel/porttagger-tweets-base - Prediction count: 46
# Using model Emanuel/porttagger-tweets-base - Prediction count: 47
# Using model Emanuel/porttagger-tweets-base - Prediction count: 48
# Using model Emanuel/porttagger-tweets-base - Prediction count: 49
# Using model Emanuel/porttagger-tweets-base - Prediction count: 50
# Using model Emanuel/porttagger-tweets-base - Prediction count: 51
# Using model Emanuel/porttagger-tweets-base - Prediction count: 52
# Using model Emanuel/porttagger-tweets-base - Prediction count: 53
# Using model Emanuel/porttagger-tweets-base - Prediction count: 54
# Using model Emanuel/porttagger-tweets-base - Prediction count: 55
# Using model Emanuel/porttagger-tweets-base - Prediction count: 56
# Using model Emanuel/porttagger-tweets-base - Prediction count: 57
# Using model Emanuel/porttagger-tweets-base - Prediction count: 58
# Using model Emanuel/porttagger-tweets-base - Prediction count: 59
# Using model Emanuel/porttagger-tweets-base - Prediction count: 60
# Using model Emanuel/porttagger-tweets-base - Prediction count: 61
# Using model Emanuel/porttagger-tweets-base - Prediction count: 62
# Using model Emanuel/porttagger-tweets-base - Prediction count: 63
# Using model Emanuel/porttagger-tweets-base - Prediction count: 64
# Using model Emanuel/porttagger-tweets-base - Prediction count: 65
# Using model Emanuel/porttagger-tweets-base - Prediction count: 66
# Using model Emanuel/porttagger-tweets-base - Prediction count: 67
# Using model Emanuel/porttagger-tweets-base - Prediction count: 68
# Using model Emanuel/porttagger-tweets-base - Prediction count: 69
# Using model Emanuel/porttagger-tweets-base - Prediction count: 70
# Using model Emanuel/porttagger-tweets-base - Prediction count: 71
# Using model Emanuel/porttagger-tweets-base - Prediction count: 72
# Using model Emanuel/porttagger-tweets-base - Prediction count: 73
# Using model Emanuel/porttagger-tweets-base - Prediction count: 74
# Using model Emanuel/porttagger-tweets-base - Prediction count: 75
# Using model Emanuel/porttagger-tweets-base - Prediction count: 76
# Using model Emanuel/porttagger-tweets-base - Prediction count: 77
# Using model Emanuel/porttagger-tweets-base - Prediction count: 78
# Using model Emanuel/porttagger-tweets-base - Prediction count: 79
# Using model Emanuel/porttagger-tweets-base - Prediction count: 80
# Using model Emanuel/porttagger-tweets-base - Prediction count: 81
# Using model Emanuel/porttagger-tweets-base - Prediction count: 82
# Using model Emanuel/porttagger-tweets-base - Prediction count: 83
# Using model Emanuel/porttagger-tweets-base - Prediction count: 84
# Using model Emanuel/porttagger-tweets-base - Prediction count: 85
# Using model Emanuel/porttagger-tweets-base - Prediction count: 86
# Using model Emanuel/porttagger-tweets-base - Prediction count: 87
# Using model Emanuel/porttagger-tweets-base - Prediction count: 88
# Using model Emanuel/porttagger-tweets-base - Prediction count: 89
# Using model Emanuel/porttagger-tweets-base - Prediction count: 90
# Using model Emanuel/porttagger-tweets-base - Prediction count: 91
# Using model Emanuel/porttagger-tweets-base - Prediction count: 92
# Using model Emanuel/porttagger-tweets-base - Prediction count: 93
# Using model Emanuel/porttagger-tweets-base - Prediction count: 94
# Using model Emanuel/porttagger-tweets-base - Prediction count: 95
# Using model Emanuel/porttagger-tweets-base - Prediction count: 96
# Using model Emanuel/porttagger-tweets-base - Prediction count: 97
# Using model Emanuel/porttagger-tweets-base - Prediction count: 98
# Using model Emanuel/porttagger-tweets-base - Prediction count: 99
# Using model Emanuel/porttagger-tweets-base - Prediction count: 100
# Using model Emanuel/porttagger-tweets-base - Prediction count: 101
# Using model Emanuel/porttagger-tweets-base - Prediction count: 102
# Using model Emanuel/porttagger-tweets-base - Prediction count: 103
# Using model Emanuel/porttagger-tweets-base - Prediction count: 104
# Using model Emanuel/porttagger-tweets-base - Prediction count: 105
# Using model Emanuel/porttagger-tweets-base - Prediction count: 106
# Using model Emanuel/porttagger-tweets-base - Prediction count: 107
# Using model Emanuel/porttagger-tweets-base - Prediction count: 108
# Using model Emanuel/porttagger-tweets-base - Prediction count: 109
# Using model Emanuel/porttagger-tweets-base - Prediction count: 110
# Using model Emanuel/porttagger-tweets-base - Prediction count: 111
# Using model Emanuel/porttagger-tweets-base - Prediction count: 112
# Using model Emanuel/porttagger-tweets-base - Prediction count: 113
# Using model Emanuel/porttagger-tweets-base - Prediction count: 114
# Using model Emanuel/porttagger-tweets-base - Prediction count: 115
# Using model Emanuel/porttagger-tweets-base - Prediction count: 116
# Using model Emanuel/porttagger-tweets-base - Prediction count: 117
# Using model Emanuel/porttagger-tweets-base - Prediction count: 118
# Using model Emanuel/porttagger-tweets-base - Prediction count: 119
# Using model Emanuel/porttagger-tweets-base - Prediction count: 120
# Using model Emanuel/porttagger-tweets-base - Prediction count: 121
# Using model Emanuel/porttagger-tweets-base - Prediction count: 122
# Using model Emanuel/porttagger-tweets-base - Prediction count: 123
# Using model Emanuel/porttagger-tweets-base - Prediction count: 124
# Using model Emanuel/porttagger-tweets-base - Prediction count: 125
# Using model Emanuel/porttagger-tweets-base - Prediction count: 126
# Using model Emanuel/porttagger-tweets-base - Prediction count: 127
# Using model Emanuel/porttagger-tweets-base - Prediction count: 128
# Using model Emanuel/porttagger-tweets-base - Prediction count: 129
# Using model Emanuel/porttagger-tweets-base - Prediction count: 130
# Using model Emanuel/porttagger-tweets-base - Prediction count: 131
# Using model Emanuel/porttagger-tweets-base - Prediction count: 132
# Using model Emanuel/porttagger-tweets-base - Prediction count: 133
# Using model Emanuel/porttagger-tweets-base - Prediction count: 134
# Using model Emanuel/porttagger-tweets-base - Prediction count: 135
# Using model Emanuel/porttagger-tweets-base - Prediction count: 136
# Using model Emanuel/porttagger-tweets-base - Prediction count: 137
# Using model Emanuel/porttagger-tweets-base - Prediction count: 138
# Using model Emanuel/porttagger-tweets-base - Prediction count: 139
# Using model Emanuel/porttagger-tweets-base - Prediction count: 140
# Using model Emanuel/porttagger-tweets-base - Prediction count: 141
# Using model Emanuel/porttagger-tweets-base - Prediction count: 142
# Using model Emanuel/porttagger-tweets-base - Prediction count: 143
# Using model Emanuel/porttagger-tweets-base - Prediction count: 144
# Using model Emanuel/porttagger-tweets-base - Prediction count: 145
# Using model Emanuel/porttagger-tweets-base - Prediction count: 146
# Using model Emanuel/porttagger-tweets-base - Prediction count: 147
# Using model Emanuel/porttagger-tweets-base - Prediction count: 148
# Using model Emanuel/porttagger-tweets-base - Prediction count: 149
# Using model Emanuel/porttagger-tweets-base - Prediction count: 150
# Using model Emanuel/porttagger-tweets-base - Prediction count: 151
# Using model Emanuel/porttagger-tweets-base - Prediction count: 152
# Using model Emanuel/porttagger-tweets-base - Prediction count: 153
# Using model Emanuel/porttagger-tweets-base - Prediction count: 154
# Using model Emanuel/porttagger-tweets-base - Prediction count: 155
# Using model Emanuel/porttagger-tweets-base - Prediction count: 156
# Using model Emanuel/porttagger-tweets-base - Prediction count: 157
# Using model Emanuel/porttagger-tweets-base - Prediction count: 158
# Using model Emanuel/porttagger-tweets-base - Prediction count: 159
# Using model Emanuel/porttagger-tweets-base - Prediction count: 160
# Using model Emanuel/porttagger-tweets-base - Prediction count: 161
# Using model Emanuel/porttagger-tweets-base - Prediction count: 162
# Using model Emanuel/porttagger-tweets-base - Prediction count: 163
# Using model Emanuel/porttagger-tweets-base - Prediction count: 164
# Using model Emanuel/porttagger-tweets-base - Prediction count: 165
# Using model Emanuel/porttagger-tweets-base - Prediction count: 166
# Using model Emanuel/porttagger-tweets-base - Prediction count: 167
# Using model Emanuel/porttagger-tweets-base - Prediction count: 168
# Using model Emanuel/porttagger-tweets-base - Prediction count: 169
# Using model Emanuel/porttagger-tweets-base - Prediction count: 170
# Using model Emanuel/porttagger-tweets-base - Prediction count: 171
# Using model Emanuel/porttagger-tweets-base - Prediction count: 172
# Using model Emanuel/porttagger-tweets-base - Prediction count: 173
# Using model Emanuel/porttagger-tweets-base - Prediction count: 174
# Using model Emanuel/porttagger-tweets-base - Prediction count: 175
# Using model Emanuel/porttagger-tweets-base - Prediction count: 176
# Using model Emanuel/porttagger-tweets-base - Prediction count: 177
# Using model Emanuel/porttagger-tweets-base - Prediction count: 178
# Using model Emanuel/porttagger-tweets-base - Prediction count: 179
# Using model Emanuel/porttagger-tweets-base - Prediction count: 180
# Using model Emanuel/porttagger-tweets-base - Prediction count: 181
# Using model Emanuel/porttagger-tweets-base - Prediction count: 182
# Using model Emanuel/porttagger-tweets-base - Prediction count: 183
# Using model Emanuel/porttagger-tweets-base - Prediction count: 184
# Using model Emanuel/porttagger-tweets-base - Prediction count: 185
# Using model Emanuel/porttagger-tweets-base - Prediction count: 186
# Using model Emanuel/porttagger-tweets-base - Prediction count: 187
# Using model Emanuel/porttagger-tweets-base - Prediction count: 188
# Using model Emanuel/porttagger-tweets-base - Prediction count: 189
# Using model Emanuel/porttagger-tweets-base - Prediction count: 190
# Using model Emanuel/porttagger-tweets-base - Prediction count: 191
# Using model Emanuel/porttagger-tweets-base - Prediction count: 192
# Using model Emanuel/porttagger-tweets-base - Prediction count: 193
# Using model Emanuel/porttagger-tweets-base - Prediction count: 194
# Using model Emanuel/porttagger-tweets-base - Prediction count: 195
# Using model Emanuel/porttagger-tweets-base - Prediction count: 196
# Using model Emanuel/porttagger-tweets-base - Prediction count: 197
# Using model Emanuel/porttagger-tweets-base - Prediction count: 198
# Using model Emanuel/porttagger-tweets-base - Prediction count: 199
# Using model Emanuel/porttagger-tweets-base - Prediction count: 200
# Using model Emanuel/porttagger-tweets-base - Prediction count: 201
# Using model Emanuel/porttagger-tweets-base - Prediction count: 202
# Using model Emanuel/porttagger-tweets-base - Prediction count: 203
# Using model Emanuel/porttagger-tweets-base - Prediction count: 204
# Using model Emanuel/porttagger-tweets-base - Prediction count: 205
# Using model Emanuel/porttagger-tweets-base - Prediction count: 206
# Using model Emanuel/porttagger-tweets-base - Prediction count: 207
# Using model Emanuel/porttagger-tweets-base - Prediction count: 208
# Using model Emanuel/porttagger-tweets-base - Prediction count: 209
# Using model Emanuel/porttagger-tweets-base - Prediction count: 210
# Using model Emanuel/porttagger-tweets-base - Prediction count: 211
# Using model Emanuel/porttagger-tweets-base - Prediction count: 212
# Using model Emanuel/porttagger-tweets-base - Prediction count: 213
# Using model Emanuel/porttagger-tweets-base - Prediction count: 214
# Using model Emanuel/porttagger-tweets-base - Prediction count: 215
# Using model Emanuel/porttagger-tweets-base - Prediction count: 216
# Using model Emanuel/porttagger-tweets-base - Prediction count: 217
# Using model Emanuel/porttagger-tweets-base - Prediction count: 218
# Using model Emanuel/porttagger-tweets-base - Prediction count: 219
# Using model Emanuel/porttagger-tweets-base - Prediction count: 220
# Using model Emanuel/porttagger-tweets-base - Prediction count: 221
# Using model Emanuel/porttagger-tweets-base - Prediction count: 222
# Using model Emanuel/porttagger-tweets-base - Prediction count: 223
# Using model Emanuel/porttagger-tweets-base - Prediction count: 224
# Using model Emanuel/porttagger-tweets-base - Prediction count: 225
# Using model Emanuel/porttagger-tweets-base - Prediction count: 226
# Using model Emanuel/porttagger-tweets-base - Prediction count: 227
# Using model Emanuel/porttagger-tweets-base - Prediction count: 228
# Using model Emanuel/porttagger-tweets-base - Prediction count: 229
# Using model Emanuel/porttagger-tweets-base - Prediction count: 230
# Using model Emanuel/porttagger-tweets-base - Prediction count: 231
# Using model Emanuel/porttagger-tweets-base - Prediction count: 232
# Using model Emanuel/porttagger-tweets-base - Prediction count: 233
# Using model Emanuel/porttagger-tweets-base - Prediction count: 234
# Using model Emanuel/porttagger-tweets-base - Prediction count: 235
# Using model Emanuel/porttagger-tweets-base - Prediction count: 236
# Using model Emanuel/porttagger-tweets-base - Prediction count: 237
# Using model Emanuel/porttagger-tweets-base - Prediction count: 238
# Using model Emanuel/porttagger-tweets-base - Prediction count: 239
# Using model Emanuel/porttagger-tweets-base - Prediction count: 240
# Using model Emanuel/porttagger-tweets-base - Prediction count: 241
# Using model Emanuel/porttagger-tweets-base - Prediction count: 242
# Using model Emanuel/porttagger-tweets-base - Prediction count: 243
# Using model Emanuel/porttagger-tweets-base - Prediction count: 244
# Using model Emanuel/porttagger-tweets-base - Prediction count: 245
# Using model Emanuel/porttagger-tweets-base - Prediction count: 246
# Using model Emanuel/porttagger-tweets-base - Prediction count: 247
# Using model Emanuel/porttagger-tweets-base - Prediction count: 248
# Using model Emanuel/porttagger-tweets-base - Prediction count: 249
# Using model Emanuel/porttagger-tweets-base - Prediction count: 250
# Using model Emanuel/porttagger-tweets-base - Prediction count: 251
# Using model Emanuel/porttagger-tweets-base - Prediction count: 252
# Using model Emanuel/porttagger-tweets-base - Prediction count: 253
# Using model Emanuel/porttagger-tweets-base - Prediction count: 254
# Using model Emanuel/porttagger-tweets-base - Prediction count: 255
# Using model Emanuel/porttagger-tweets-base - Prediction count: 256
# Using model Emanuel/porttagger-tweets-base - Prediction count: 257
# Using model Emanuel/porttagger-tweets-base - Prediction count: 258
# Using model Emanuel/porttagger-tweets-base - Prediction count: 259
# Using model Emanuel/porttagger-tweets-base - Prediction count: 260
# Using model Emanuel/porttagger-tweets-base - Prediction count: 261
# Using model Emanuel/porttagger-tweets-base - Prediction count: 262
# Using model Emanuel/porttagger-tweets-base - Prediction count: 263
# Using model Emanuel/porttagger-tweets-base - Prediction count: 264
# Using model Emanuel/porttagger-tweets-base - Prediction count: 265
# Using model Emanuel/porttagger-tweets-base - Prediction count: 266
# Using model Emanuel/porttagger-tweets-base - Prediction count: 267
# Using model Emanuel/porttagger-tweets-base - Prediction count: 268
# Using model Emanuel/porttagger-tweets-base - Prediction count: 269
# Using model Emanuel/porttagger-tweets-base - Prediction count: 270
# Using model Emanuel/porttagger-tweets-base - Prediction count: 271
# Using model Emanuel/porttagger-tweets-base - Prediction count: 272
# Using model Emanuel/porttagger-tweets-base - Prediction count: 273
# Using model Emanuel/porttagger-tweets-base - Prediction count: 274
# Using model Emanuel/porttagger-tweets-base - Prediction count: 275
# Using model Emanuel/porttagger-tweets-base - Prediction count: 276
# Using model Emanuel/porttagger-tweets-base - Prediction count: 277
# Using model Emanuel/porttagger-tweets-base - Prediction count: 278
# Using model Emanuel/porttagger-tweets-base - Prediction count: 279
# Using model Emanuel/porttagger-tweets-base - Prediction count: 280
# Using model Emanuel/porttagger-tweets-base - Prediction count: 281
# Using model Emanuel/porttagger-tweets-base - Prediction count: 282
# Using model Emanuel/porttagger-tweets-base - Prediction count: 283
# Using model Emanuel/porttagger-tweets-base - Prediction count: 284
# Using model Emanuel/porttagger-tweets-base - Prediction count: 285
# Using model Emanuel/porttagger-tweets-base - Prediction count: 286
# Using model Emanuel/porttagger-tweets-base - Prediction count: 287
# Using model Emanuel/porttagger-tweets-base - Prediction count: 288
# Using model Emanuel/porttagger-tweets-base - Prediction count: 289
# Using model Emanuel/porttagger-tweets-base - Prediction count: 290
# Using model Emanuel/porttagger-tweets-base - Prediction count: 291
# Using model Emanuel/porttagger-tweets-base - Prediction count: 292
# Using model Emanuel/porttagger-tweets-base - Prediction count: 293
# Using model Emanuel/porttagger-tweets-base - Prediction count: 294
# Using model Emanuel/porttagger-tweets-base - Prediction count: 295
# Using model Emanuel/porttagger-tweets-base - Prediction count: 296
# Using model Emanuel/porttagger-tweets-base - Prediction count: 297
# Using model Emanuel/porttagger-tweets-base - Prediction count: 298
# Using model Emanuel/porttagger-tweets-base - Prediction count: 299
# Using model Emanuel/porttagger-tweets-base - Prediction count: 300
# Using model Emanuel/porttagger-tweets-base - Prediction count: 301
# Using model Emanuel/porttagger-tweets-base - Prediction count: 302
# Using model Emanuel/porttagger-tweets-base - Prediction count: 303
# Using model Emanuel/porttagger-tweets-base - Prediction count: 304
# Using model Emanuel/porttagger-tweets-base - Prediction count: 305
# Using model Emanuel/porttagger-tweets-base - Prediction count: 306
# Using model Emanuel/porttagger-tweets-base - Prediction count: 307
# Using model Emanuel/porttagger-tweets-base - Prediction count: 308
# Using model Emanuel/porttagger-tweets-base - Prediction count: 309
# Using model Emanuel/porttagger-tweets-base - Prediction count: 310
# Using model Emanuel/porttagger-tweets-base - Prediction count: 311
# Using model Emanuel/porttagger-tweets-base - Prediction count: 312
# Using model Emanuel/porttagger-tweets-base - Prediction count: 313
# Using model Emanuel/porttagger-tweets-base - Prediction count: 314
# Using model Emanuel/porttagger-tweets-base - Prediction count: 315
# Using model Emanuel/porttagger-tweets-base - Prediction count: 316
# Using model Emanuel/porttagger-tweets-base - Prediction count: 317
# Using model Emanuel/porttagger-tweets-base - Prediction count: 318
# Using model Emanuel/porttagger-tweets-base - Prediction count: 319
# Using model Emanuel/porttagger-tweets-base - Prediction count: 320
# Using model Emanuel/porttagger-tweets-base - Prediction count: 321
# Using model Emanuel/porttagger-tweets-base - Prediction count: 322
# Using model Emanuel/porttagger-tweets-base - Prediction count: 323
# Using model Emanuel/porttagger-tweets-base - Prediction count: 324
# Using model Emanuel/porttagger-tweets-base - Prediction count: 325
# Using model Emanuel/porttagger-tweets-base - Prediction count: 326
# Using model Emanuel/porttagger-tweets-base - Prediction count: 327
# Using model Emanuel/porttagger-tweets-base - Prediction count: 328
# Using model Emanuel/porttagger-tweets-base - Prediction count: 329
# Using model Emanuel/porttagger-tweets-base - Prediction count: 330
# Using model Emanuel/porttagger-tweets-base - Prediction count: 331
# Using model Emanuel/porttagger-tweets-base - Prediction count: 332
# Using model Emanuel/porttagger-tweets-base - Prediction count: 333
# Using model Emanuel/porttagger-tweets-base - Prediction count: 334
# Using model Emanuel/porttagger-tweets-base - Prediction count: 335
# Using model Emanuel/porttagger-tweets-base - Prediction count: 336
# Using model Emanuel/porttagger-tweets-base - Prediction count: 337
# Using model Emanuel/porttagger-tweets-base - Prediction count: 338
# Using model Emanuel/porttagger-tweets-base - Prediction count: 339
# Using model Emanuel/porttagger-tweets-base - Prediction count: 340
# Using model Emanuel/porttagger-tweets-base - Prediction count: 341
# Using model Emanuel/porttagger-tweets-base - Prediction count: 342
# Using model Emanuel/porttagger-tweets-base - Prediction count: 343
# Using model Emanuel/porttagger-tweets-base - Prediction count: 344
# Using model Emanuel/porttagger-tweets-base - Prediction count: 345
# Using model Emanuel/porttagger-tweets-base - Prediction count: 346
# Using model Emanuel/porttagger-tweets-base - Prediction count: 347
# Using model Emanuel/porttagger-tweets-base - Prediction count: 348
# Using model Emanuel/porttagger-tweets-base - Prediction count: 349
# Using model Emanuel/porttagger-tweets-base - Prediction count: 350
# Using model Emanuel/porttagger-tweets-base - Prediction count: 351
# Using model Emanuel/porttagger-tweets-base - Prediction count: 352
# Using model Emanuel/porttagger-tweets-base - Prediction count: 353
# Using model Emanuel/porttagger-tweets-base - Prediction count: 354
# Using model Emanuel/porttagger-tweets-base - Prediction count: 355
# Using model Emanuel/porttagger-tweets-base - Prediction count: 356
# Using model Emanuel/porttagger-tweets-base - Prediction count: 357
# Using model Emanuel/porttagger-tweets-base - Prediction count: 358
# Using model Emanuel/porttagger-tweets-base - Prediction count: 359
# Using model Emanuel/porttagger-tweets-base - Prediction count: 360
# Using model Emanuel/porttagger-tweets-base - Prediction count: 361
# Using model Emanuel/porttagger-tweets-base - Prediction count: 362
# Using model Emanuel/porttagger-tweets-base - Prediction count: 363
# Using model Emanuel/porttagger-tweets-base - Prediction count: 364
# Using model Emanuel/porttagger-tweets-base - Prediction count: 365
# Using model Emanuel/porttagger-tweets-base - Prediction count: 366
# Using model Emanuel/porttagger-tweets-base - Prediction count: 367
# Using model Emanuel/porttagger-tweets-base - Prediction count: 368
# Using model Emanuel/porttagger-tweets-base - Prediction count: 369
# Using model Emanuel/porttagger-tweets-base - Prediction count: 370
# Using model Emanuel/porttagger-tweets-base - Prediction count: 371
# Using model Emanuel/porttagger-tweets-base - Prediction count: 372
# Using model Emanuel/porttagger-tweets-base - Prediction count: 373
# Using model Emanuel/porttagger-tweets-base - Prediction count: 374
# Using model Emanuel/porttagger-tweets-base - Prediction count: 375
# Using model Emanuel/porttagger-tweets-base - Prediction count: 376
# Using model Emanuel/porttagger-tweets-base - Prediction count: 377
# Using model Emanuel/porttagger-tweets-base - Prediction count: 378
# Using model Emanuel/porttagger-tweets-base - Prediction count: 379
# Using model Emanuel/porttagger-tweets-base - Prediction count: 380
# Using model Emanuel/porttagger-tweets-base - Prediction count: 381
# Using model Emanuel/porttagger-tweets-base - Prediction count: 382
# Using model Emanuel/porttagger-tweets-base - Prediction count: 383
# Using model Emanuel/porttagger-tweets-base - Prediction count: 384
# Using model Emanuel/porttagger-tweets-base - Prediction count: 385
# Using model Emanuel/porttagger-tweets-base - Prediction count: 386
# Using model Emanuel/porttagger-tweets-base - Prediction count: 387
# Using model Emanuel/porttagger-tweets-base - Prediction count: 388
# Using model Emanuel/porttagger-tweets-base - Prediction count: 389
# Using model Emanuel/porttagger-tweets-base - Prediction count: 390
# Using model Emanuel/porttagger-tweets-base - Prediction count: 391
# Using model Emanuel/porttagger-tweets-base - Prediction count: 392
# Using model Emanuel/porttagger-tweets-base - Prediction count: 393
# Using model Emanuel/porttagger-tweets-base - Prediction count: 394
# Using model Emanuel/porttagger-tweets-base - Prediction count: 395
# Using model Emanuel/porttagger-tweets-base - Prediction count: 396
# Using model Emanuel/porttagger-tweets-base - Prediction count: 397
# Using model Emanuel/porttagger-tweets-base - Prediction count: 398
# Using model Emanuel/porttagger-tweets-base - Prediction count: 399
# Using model Emanuel/porttagger-tweets-base - Prediction count: 400
# Using model Emanuel/porttagger-tweets-base - Prediction count: 401
# Using model Emanuel/porttagger-tweets-base - Prediction count: 402
# Using model Emanuel/porttagger-tweets-base - Prediction count: 403
# Using model Emanuel/porttagger-tweets-base - Prediction count: 404
# Using model Emanuel/porttagger-tweets-base - Prediction count: 405
# Using model Emanuel/porttagger-tweets-base - Prediction count: 406
# Using model Emanuel/porttagger-tweets-base - Prediction count: 407
# Using model Emanuel/porttagger-tweets-base - Prediction count: 408
# Using model Emanuel/porttagger-tweets-base - Prediction count: 409
# Using model Emanuel/porttagger-tweets-base - Prediction count: 410
# Using model Emanuel/porttagger-tweets-base - Prediction count: 411
# Using model Emanuel/porttagger-tweets-base - Prediction count: 412
# Using model Emanuel/porttagger-tweets-base - Prediction count: 413
# Using model Emanuel/porttagger-tweets-base - Prediction count: 414
# Using model Emanuel/porttagger-tweets-base - Prediction count: 415
# Using model Emanuel/porttagger-tweets-base - Prediction count: 416
# Using model Emanuel/porttagger-tweets-base - Prediction count: 417
# Using model Emanuel/porttagger-tweets-base - Prediction count: 418
# Using model Emanuel/porttagger-tweets-base - Prediction count: 419
# Using model Emanuel/porttagger-tweets-base - Prediction count: 420
# Using model Emanuel/porttagger-tweets-base - Prediction count: 421
# Using model Emanuel/porttagger-tweets-base - Prediction count: 422
# Using model Emanuel/porttagger-tweets-base - Prediction count: 423
# Using model Emanuel/porttagger-tweets-base - Prediction count: 424
# Using model Emanuel/porttagger-tweets-base - Prediction count: 425
# Using model Emanuel/porttagger-tweets-base - Prediction count: 426
# Using model Emanuel/porttagger-tweets-base - Prediction count: 427
# Using model Emanuel/porttagger-tweets-base - Prediction count: 428
# Using model Emanuel/porttagger-tweets-base - Prediction count: 429
# Using model Emanuel/porttagger-tweets-base - Prediction count: 430
# Using model Emanuel/porttagger-tweets-base - Prediction count: 431
# Using model Emanuel/porttagger-tweets-base - Prediction count: 432
# Using model Emanuel/porttagger-tweets-base - Prediction count: 433
# Using model Emanuel/porttagger-tweets-base - Prediction count: 434
# Using model Emanuel/porttagger-tweets-base - Prediction count: 435
# Using model Emanuel/porttagger-tweets-base - Prediction count: 436
# Using model Emanuel/porttagger-tweets-base - Prediction count: 437
# Using model Emanuel/porttagger-tweets-base - Prediction count: 438
# Using model Emanuel/porttagger-tweets-base - Prediction count: 439
# Using model Emanuel/porttagger-tweets-base - Prediction count: 440
# Using model Emanuel/porttagger-tweets-base - Prediction count: 441
# Using model Emanuel/porttagger-tweets-base - Prediction count: 442
# Using model Emanuel/porttagger-tweets-base - Prediction count: 443
# Using model Emanuel/porttagger-tweets-base - Prediction count: 444
# Using model Emanuel/porttagger-tweets-base - Prediction count: 445
# Using model Emanuel/porttagger-tweets-base - Prediction count: 446
# Using model Emanuel/porttagger-tweets-base - Prediction count: 447
# Using model Emanuel/porttagger-tweets-base - Prediction count: 448
# Using model Emanuel/porttagger-tweets-base - Prediction count: 449
# Using model Emanuel/porttagger-tweets-base - Prediction count: 450
# Using model Emanuel/porttagger-tweets-base - Prediction count: 451
# Using model Emanuel/porttagger-tweets-base - Prediction count: 452
# Using model Emanuel/porttagger-tweets-base - Prediction count: 453
# Using model Emanuel/porttagger-tweets-base - Prediction count: 454
# Using model Emanuel/porttagger-tweets-base - Prediction count: 455
# Using model Emanuel/porttagger-tweets-base - Prediction count: 456
# Using model Emanuel/porttagger-tweets-base - Prediction count: 457
# Using model Emanuel/porttagger-tweets-base - Prediction count: 458
# Using model Emanuel/porttagger-tweets-base - Prediction count: 459
# Using model Emanuel/porttagger-tweets-base - Prediction count: 460
# Using model Emanuel/porttagger-tweets-base - Prediction count: 461
# Using model Emanuel/porttagger-tweets-base - Prediction count: 462
# Using model Emanuel/porttagger-tweets-base - Prediction count: 463
# Using model Emanuel/porttagger-tweets-base - Prediction count: 464
# Using model Emanuel/porttagger-tweets-base - Prediction count: 465
# Using model Emanuel/porttagger-tweets-base - Prediction count: 466
# Using model Emanuel/porttagger-tweets-base - Prediction count: 467
# Using model Emanuel/porttagger-tweets-base - Prediction count: 468
# Using model Emanuel/porttagger-tweets-base - Prediction count: 469
# Using model Emanuel/porttagger-tweets-base - Prediction count: 470
# Using model Emanuel/porttagger-tweets-base - Prediction count: 471
# Using model Emanuel/porttagger-tweets-base - Prediction count: 472
# Using model Emanuel/porttagger-tweets-base - Prediction count: 473
# Using model Emanuel/porttagger-tweets-base - Prediction count: 474
# Using model Emanuel/porttagger-tweets-base - Prediction count: 475
# Using model Emanuel/porttagger-tweets-base - Prediction count: 476
# Using model Emanuel/porttagger-tweets-base - Prediction count: 477
# Using model Emanuel/porttagger-tweets-base - Prediction count: 478
# Using model Emanuel/porttagger-tweets-base - Prediction count: 479
# Using model Emanuel/porttagger-tweets-base - Prediction count: 480
# Using model Emanuel/porttagger-tweets-base - Prediction count: 481
# Using model Emanuel/porttagger-tweets-base - Prediction count: 482
# Using model Emanuel/porttagger-tweets-base - Prediction count: 483
# Using model Emanuel/porttagger-tweets-base - Prediction count: 484
# Using model Emanuel/porttagger-tweets-base - Prediction count: 485
# Using model Emanuel/porttagger-tweets-base - Prediction count: 486
# Using model Emanuel/porttagger-tweets-base - Prediction count: 487
# Using model Emanuel/porttagger-tweets-base - Prediction count: 488
# Using model Emanuel/porttagger-tweets-base - Prediction count: 489
# Using model Emanuel/porttagger-tweets-base - Prediction count: 490
# Using model Emanuel/porttagger-tweets-base - Prediction count: 491
# Using model Emanuel/porttagger-tweets-base - Prediction count: 492
# Using model Emanuel/porttagger-tweets-base - Prediction count: 493
# Using model Emanuel/porttagger-tweets-base - Prediction count: 494
# Using model Emanuel/porttagger-tweets-base - Prediction count: 495
# Using model Emanuel/porttagger-tweets-base - Prediction count: 496
# Using model Emanuel/porttagger-tweets-base - Prediction count: 497
# Using model Emanuel/porttagger-tweets-base - Prediction count: 498
# Using model Emanuel/porttagger-tweets-base - Prediction count: 499
# Using model Emanuel/porttagger-tweets-base - Prediction count: 500
# Using model Emanuel/porttagger-tweets-base - Prediction count: 501
# Using model Emanuel/porttagger-tweets-base - Prediction count: 502
# Using model Emanuel/porttagger-tweets-base - Prediction count: 503
# Using model Emanuel/porttagger-tweets-base - Prediction count: 504
# Using model Emanuel/porttagger-tweets-base - Prediction count: 505
# Using model Emanuel/porttagger-tweets-base - Prediction count: 506
# Using model Emanuel/porttagger-tweets-base - Prediction count: 507
# Using model Emanuel/porttagger-tweets-base - Prediction count: 508
# Using model Emanuel/porttagger-tweets-base - Prediction count: 509
# Using model Emanuel/porttagger-tweets-base - Prediction count: 510
# Using model Emanuel/porttagger-tweets-base - Prediction count: 511
# Using model Emanuel/porttagger-tweets-base - Prediction count: 512
# Using model Emanuel/porttagger-tweets-base - Prediction count: 513
# Using model Emanuel/porttagger-tweets-base - Prediction count: 514
# Using model Emanuel/porttagger-tweets-base - Prediction count: 515
# Using model Emanuel/porttagger-tweets-base - Prediction count: 516
# Using model Emanuel/porttagger-tweets-base - Prediction count: 517
# Using model Emanuel/porttagger-tweets-base - Prediction count: 518
# Using model Emanuel/porttagger-tweets-base - Prediction count: 519
# Using model Emanuel/porttagger-tweets-base - Prediction count: 520
# Using model Emanuel/porttagger-tweets-base - Prediction count: 521
# Using model Emanuel/porttagger-tweets-base - Prediction count: 522
# Using model Emanuel/porttagger-tweets-base - Prediction count: 523
# Using model Emanuel/porttagger-tweets-base - Prediction count: 524
# Using model Emanuel/porttagger-tweets-base - Prediction count: 525
# Using model Emanuel/porttagger-tweets-base - Prediction count: 526
# Using model Emanuel/porttagger-tweets-base - Prediction count: 527
# Using model Emanuel/porttagger-tweets-base - Prediction count: 528
# Using model Emanuel/porttagger-tweets-base - Prediction count: 529
# Using model Emanuel/porttagger-tweets-base - Prediction count: 530
# Using model Emanuel/porttagger-tweets-base - Prediction count: 531
# Using model Emanuel/porttagger-tweets-base - Prediction count: 532
# Using model Emanuel/porttagger-tweets-base - Prediction count: 533
# Using model Emanuel/porttagger-tweets-base - Prediction count: 534
# Using model Emanuel/porttagger-tweets-base - Prediction count: 535
# Using model Emanuel/porttagger-tweets-base - Prediction count: 536
# Using model Emanuel/porttagger-tweets-base - Prediction count: 537
# Using model Emanuel/porttagger-tweets-base - Prediction count: 538
# Using model Emanuel/porttagger-tweets-base - Prediction count: 539
# Using model Emanuel/porttagger-tweets-base - Prediction count: 540
# Using model Emanuel/porttagger-tweets-base - Prediction count: 541
# Using model Emanuel/porttagger-tweets-base - Prediction count: 542
# Using model Emanuel/porttagger-tweets-base - Prediction count: 543
# Using model Emanuel/porttagger-tweets-base - Prediction count: 544
# Using model Emanuel/porttagger-tweets-base - Prediction count: 545
# Using model Emanuel/porttagger-tweets-base - Prediction count: 546
# Using model Emanuel/porttagger-tweets-base - Prediction count: 547
# Using model Emanuel/porttagger-tweets-base - Prediction count: 548
# Using model Emanuel/porttagger-tweets-base - Prediction count: 549
# Using model Emanuel/porttagger-tweets-base - Prediction count: 550
# Using model Emanuel/porttagger-tweets-base - Prediction count: 551
# Using model Emanuel/porttagger-tweets-base - Prediction count: 552
# Using model Emanuel/porttagger-tweets-base - Prediction count: 553
# Using model Emanuel/porttagger-tweets-base - Prediction count: 554
# Using model Emanuel/porttagger-tweets-base - Prediction count: 555
# Using model Emanuel/porttagger-tweets-base - Prediction count: 556
# Using model Emanuel/porttagger-tweets-base - Prediction count: 557
# Using model Emanuel/porttagger-tweets-base - Prediction count: 558
# Using model Emanuel/porttagger-tweets-base - Prediction count: 559
# Using model Emanuel/porttagger-tweets-base - Prediction count: 560
# Using model Emanuel/porttagger-tweets-base - Prediction count: 561
# Using model Emanuel/porttagger-tweets-base - Prediction count: 562
# Using model Emanuel/porttagger-tweets-base - Prediction count: 563
# Using model Emanuel/porttagger-tweets-base - Prediction count: 564
# Using model Emanuel/porttagger-tweets-base - Prediction count: 565
# Using model Emanuel/porttagger-tweets-base - Prediction count: 566
# Using model Emanuel/porttagger-tweets-base - Prediction count: 567
# Using model Emanuel/porttagger-tweets-base - Prediction count: 568
# Using model Emanuel/porttagger-tweets-base - Prediction count: 569
# Using model Emanuel/porttagger-tweets-base - Prediction count: 570
# Using model Emanuel/porttagger-tweets-base - Prediction count: 571
# Using model Emanuel/porttagger-tweets-base - Prediction count: 572
# Using model Emanuel/porttagger-tweets-base - Prediction count: 573
# Using model Emanuel/porttagger-tweets-base - Prediction count: 574
# Using model Emanuel/porttagger-tweets-base - Prediction count: 575
# Using model Emanuel/porttagger-tweets-base - Prediction count: 576
# Using model Emanuel/porttagger-tweets-base - Prediction count: 577
# Using model Emanuel/porttagger-tweets-base - Prediction count: 578
# Using model Emanuel/porttagger-tweets-base - Prediction count: 579
# Using model Emanuel/porttagger-tweets-base - Prediction count: 580
# Using model Emanuel/porttagger-tweets-base - Prediction count: 581
# Using model Emanuel/porttagger-tweets-base - Prediction count: 582
# Using model Emanuel/porttagger-tweets-base - Prediction count: 583
# Using model Emanuel/porttagger-tweets-base - Prediction count: 584
# Using model Emanuel/porttagger-tweets-base - Prediction count: 585
# Using model Emanuel/porttagger-tweets-base - Prediction count: 586
# Using model Emanuel/porttagger-tweets-base - Prediction count: 587
# Using model Emanuel/porttagger-tweets-base - Prediction count: 588
# Using model Emanuel/porttagger-tweets-base - Prediction count: 589
# Using model Emanuel/porttagger-tweets-base - Prediction count: 590
# Using model Emanuel/porttagger-tweets-base - Prediction count: 591
# Using model Emanuel/porttagger-tweets-base - Prediction count: 592
# Using model Emanuel/porttagger-tweets-base - Prediction count: 593
# Using model Emanuel/porttagger-tweets-base - Prediction count: 594
# Using model Emanuel/porttagger-tweets-base - Prediction count: 595
# Using model Emanuel/porttagger-tweets-base - Prediction count: 596
# Using model Emanuel/porttagger-tweets-base - Prediction count: 597
# Using model Emanuel/porttagger-tweets-base - Prediction count: 598
# Using model Emanuel/porttagger-tweets-base - Prediction count: 599
# Using model Emanuel/porttagger-tweets-base - Prediction count: 600
# Using model Emanuel/porttagger-tweets-base - Prediction count: 601
# Using model Emanuel/porttagger-tweets-base - Prediction count: 602
# Using model Emanuel/porttagger-tweets-base - Prediction count: 603
# Using model Emanuel/porttagger-tweets-base - Prediction count: 604
# Using model Emanuel/porttagger-tweets-base - Prediction count: 605
# Using model Emanuel/porttagger-tweets-base - Prediction count: 606
# Using model Emanuel/porttagger-tweets-base - Prediction count: 607
# Using model Emanuel/porttagger-tweets-base - Prediction count: 608
# Using model Emanuel/porttagger-tweets-base - Prediction count: 609
# Using model Emanuel/porttagger-tweets-base - Prediction count: 610
# Using model Emanuel/porttagger-tweets-base - Prediction count: 611
# Using model Emanuel/porttagger-tweets-base - Prediction count: 612
# Using model Emanuel/porttagger-tweets-base - Prediction count: 613
# Using model Emanuel/porttagger-tweets-base - Prediction count: 614
# Using model Emanuel/porttagger-tweets-base - Prediction count: 615
# Using model Emanuel/porttagger-tweets-base - Prediction count: 616
# Using model Emanuel/porttagger-tweets-base - Prediction count: 617
# Using model Emanuel/porttagger-tweets-base - Prediction count: 618
# Using model Emanuel/porttagger-tweets-base - Prediction count: 619
# Using model Emanuel/porttagger-tweets-base - Prediction count: 620
# Using model Emanuel/porttagger-tweets-base - Prediction count: 621
# Using model Emanuel/porttagger-tweets-base - Prediction count: 622
# Using model Emanuel/porttagger-tweets-base - Prediction count: 623
# Using model Emanuel/porttagger-tweets-base - Prediction count: 624
# Using model Emanuel/porttagger-tweets-base - Prediction count: 625
# Using model Emanuel/porttagger-tweets-base - Prediction count: 626
# Using model Emanuel/porttagger-tweets-base - Prediction count: 627
# Using model Emanuel/porttagger-tweets-base - Prediction count: 628
# Using model Emanuel/porttagger-tweets-base - Prediction count: 629
# Using model Emanuel/porttagger-tweets-base - Prediction count: 630
# Using model Emanuel/porttagger-tweets-base - Prediction count: 631
# Using model Emanuel/porttagger-tweets-base - Prediction count: 632
# Using model Emanuel/porttagger-tweets-base - Prediction count: 633
# Using model Emanuel/porttagger-tweets-base - Prediction count: 634
# Using model Emanuel/porttagger-tweets-base - Prediction count: 635
# Using model Emanuel/porttagger-tweets-base - Prediction count: 636
# Using model Emanuel/porttagger-tweets-base - Prediction count: 637
# Using model Emanuel/porttagger-tweets-base - Prediction count: 638
# Using model Emanuel/porttagger-tweets-base - Prediction count: 639
# Using model Emanuel/porttagger-tweets-base - Prediction count: 640
# Using model Emanuel/porttagger-tweets-base - Prediction count: 641
# Using model Emanuel/porttagger-tweets-base - Prediction count: 642
# Using model Emanuel/porttagger-tweets-base - Prediction count: 643
# Using model Emanuel/porttagger-tweets-base - Prediction count: 644
# Using model Emanuel/porttagger-tweets-base - Prediction count: 645
# Using model Emanuel/porttagger-tweets-base - Prediction count: 646
# Using model Emanuel/porttagger-tweets-base - Prediction count: 647
# Using model Emanuel/porttagger-tweets-base - Prediction count: 648
# Using model Emanuel/porttagger-tweets-base - Prediction count: 649
# Using model Emanuel/porttagger-tweets-base - Prediction count: 650
# Using model Emanuel/porttagger-tweets-base - Prediction count: 651
# Using model Emanuel/porttagger-tweets-base - Prediction count: 652
# Using model Emanuel/porttagger-tweets-base - Prediction count: 653
# Using model Emanuel/porttagger-tweets-base - Prediction count: 654
# Using model Emanuel/porttagger-tweets-base - Prediction count: 655
# Using model Emanuel/porttagger-tweets-base - Prediction count: 656
# Using model Emanuel/porttagger-tweets-base - Prediction count: 657
# Using model Emanuel/porttagger-tweets-base - Prediction count: 658
# Using model Emanuel/porttagger-tweets-base - Prediction count: 659
# Using model Emanuel/porttagger-tweets-base - Prediction count: 660
# Using model Emanuel/porttagger-tweets-base - Prediction count: 661
# Using model Emanuel/porttagger-tweets-base - Prediction count: 662
# Using model Emanuel/porttagger-tweets-base - Prediction count: 663
# Using model Emanuel/porttagger-tweets-base - Prediction count: 664
# Using model Emanuel/porttagger-tweets-base - Prediction count: 665
# Using model Emanuel/porttagger-tweets-base - Prediction count: 666
# Using model Emanuel/porttagger-tweets-base - Prediction count: 667
# Using model Emanuel/porttagger-tweets-base - Prediction count: 668
# Using model Emanuel/porttagger-tweets-base - Prediction count: 669
# Using model Emanuel/porttagger-tweets-base - Prediction count: 670
# Using model Emanuel/porttagger-tweets-base - Prediction count: 671
# Using model Emanuel/porttagger-tweets-base - Prediction count: 672
# Using model Emanuel/porttagger-tweets-base - Prediction count: 673
# Using model Emanuel/porttagger-tweets-base - Prediction count: 674
# Using model Emanuel/porttagger-tweets-base - Prediction count: 675
# Using model Emanuel/porttagger-tweets-base - Prediction count: 676
# Using model Emanuel/porttagger-tweets-base - Prediction count: 677
# Using model Emanuel/porttagger-tweets-base - Prediction count: 678
# Using model Emanuel/porttagger-tweets-base - Prediction count: 679
# Using model Emanuel/porttagger-tweets-base - Prediction count: 680
# Using model Emanuel/porttagger-tweets-base - Prediction count: 681
# Using model Emanuel/porttagger-tweets-base - Prediction count: 682
# Using model Emanuel/porttagger-tweets-base - Prediction count: 683
# Using model Emanuel/porttagger-tweets-base - Prediction count: 684
# Using model Emanuel/porttagger-tweets-base - Prediction count: 685
# Using model Emanuel/porttagger-tweets-base - Prediction count: 686
# Using model Emanuel/porttagger-tweets-base - Prediction count: 687
# Using model Emanuel/porttagger-tweets-base - Prediction count: 688
# Using model Emanuel/porttagger-tweets-base - Prediction count: 689
# Using model Emanuel/porttagger-tweets-base - Prediction count: 690
# Using model Emanuel/porttagger-tweets-base - Prediction count: 691
# Using model Emanuel/porttagger-tweets-base - Prediction count: 692
# Using model Emanuel/porttagger-tweets-base - Prediction count: 693
# Using model Emanuel/porttagger-tweets-base - Prediction count: 694
# Using model Emanuel/porttagger-tweets-base - Prediction count: 695
# Using model Emanuel/porttagger-tweets-base - Prediction count: 696
# Using model Emanuel/porttagger-tweets-base - Prediction count: 697
# Using model Emanuel/porttagger-tweets-base - Prediction count: 698
# Using model Emanuel/porttagger-tweets-base - Prediction count: 699
# Using model Emanuel/porttagger-tweets-base - Prediction count: 700
# Using model Emanuel/porttagger-tweets-base - Prediction count: 701
# Using model Emanuel/porttagger-tweets-base - Prediction count: 702
# Using model Emanuel/porttagger-tweets-base - Prediction count: 703
# Using model Emanuel/porttagger-tweets-base - Prediction count: 704
# Using model Emanuel/porttagger-tweets-base - Prediction count: 705
# Using model Emanuel/porttagger-tweets-base - Prediction count: 706
# Using model Emanuel/porttagger-tweets-base - Prediction count: 707
# Using model Emanuel/porttagger-tweets-base - Prediction count: 708
# Using model Emanuel/porttagger-tweets-base - Prediction count: 709
# Using model Emanuel/porttagger-tweets-base - Prediction count: 710
# Using model Emanuel/porttagger-tweets-base - Prediction count: 711
# Using model Emanuel/porttagger-tweets-base - Prediction count: 712
# Using model Emanuel/porttagger-tweets-base - Prediction count: 713
# Using model Emanuel/porttagger-tweets-base - Prediction count: 714
# Using model Emanuel/porttagger-tweets-base - Prediction count: 715
# ...
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3808
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3809
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3810
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3811
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3812
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3813
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3814
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3815
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3816
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3817
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3818
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3819
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3820
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3821
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3822
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3823
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3824
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3825
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3826
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3827
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3828
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3829
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3830
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3831
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3832
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3833
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3834
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3835
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3836
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3837
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3838
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3839
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3840
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3841
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3842
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3843
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3844
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3845
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3846
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3847
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3848
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3849
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3850
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3851
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3852
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3853
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3854
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3855
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3856
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3857
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3858
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3859
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3860
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3861
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3862
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3863
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3864
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3865
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3866
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3867
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3868
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3869
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3870
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3871
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3872
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3873
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3874
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3875
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3876
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3877
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3878
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3879
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3880
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3881
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3882
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3883
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3884
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3885
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3886
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3887
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3888
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3889
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3890
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3891
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3892
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3893
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3894
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3895
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3896
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3897
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3898
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3899
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3900
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3901
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3902
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3903
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3904
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3905
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3906
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3907
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3908
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3909
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3910
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3911
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3912
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3913
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3914
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3915
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3916
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3917
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3918
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3919
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3920
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3921
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3922
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3923
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3924
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3925
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3926
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3927
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3928
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3929
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3930
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3931
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3932
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3933
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3934
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3935
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3936
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3937
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3938
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3939
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3940
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3941
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3942
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3943
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3944
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3945
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3946
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3947
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3948
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3949
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3950
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3951
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3952
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3953
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3954
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3955
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3956
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3957
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3958
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3959
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3960
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3961
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3962
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3963
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3964
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3965
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3966
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3967
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3968
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3969
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3970
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3971
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3972
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3973
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3974
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3975
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3976
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3977
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3978
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3979
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3980
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3981
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3982
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3983
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3984
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3985
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3986
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3987
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3988
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3989
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3990
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3991
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3992
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3993
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3994
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3995
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3996
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3997
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3998
# Using model Emanuel/porttagger-tweets-base - Prediction count: 3999
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4000
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4001
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4002
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4003
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4004
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4005
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4006
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4007
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4008
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4009
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4010
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4011
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4012
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4013
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4014
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4015
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4016
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4017
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4018
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4019
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4020
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4021
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4022
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4023
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4024
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4025
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4026
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4027
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4028
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4029
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4030
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4031
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4032
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4033
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4034
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4035
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4036
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4037
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4038
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4039
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4040
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4041
# Using model Emanuel/porttagger-tweets-base - Prediction count: 4042
